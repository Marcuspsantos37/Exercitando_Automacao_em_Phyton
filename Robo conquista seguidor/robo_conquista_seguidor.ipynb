# %%
from PIL import Image
import pyautogui
import random
from random import randint
import time

# %% [markdown]
# * BOTÃO SEGUIR

# %%
time.sleep(2)
contador = 0
for i in range(500):
    contador += 1
    time.sleep(random.randint(4,25))

    if pyautogui.locateOnScreen('seguir_5.png'):
        pyautogui.click('seguir_5.png')
        #time.sleep(random.randint(3,10))
        #pyautogui.press('tab',press=3)
        print('Encontrei com Método 1: Click')
    else:
        time.sleep(random.randint(3,55))
        #pyautogui.press('tab', presses=8)
        pyautogui.press('end')
        
        #time.sleep(random.randint(4,70))
        #pyautogui.click(x=1330, y=396)
        #time.sleep(random.randint(5,10))
        #pyautogui.press('pagedown')
        print('Descendo a tela!')

    print(contador)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\marcu\Documents\Robo conquista seguidor\robo_conquista_seguidor.ipynb Célula 3 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/marcu/Documents/Robo%20conquista%20seguidor/robo_conquista_seguidor.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a>     print('Encontrei com Método 1: Click')
#      <a href='vscode-notebook-cell:/c%3A/Users/marcu/Documents/Robo%20conquista%20seguidor/robo_conquista_seguidor.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> else:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/marcu/Documents/Robo%20conquista%20seguidor/robo_conquista_seguidor.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a>     time.sleep(random.randint(3,55))
#      <a href='vscode-notebook-cell:/c%3A/Users/marcu/Documents/Robo%20conquista%20seguidor/robo_conquista_seguidor.ipynb#W2sZmlsZQ%3D%3D?line=13'>14</a>     #pyautogui.press('tab', presses=8)
# ...

# %%
time.sleep(2)
contador = 0
for i in range(500):
    contador += 1
    time.sleep(random.randint(2,3))

    if pyautogui.locateOnScreen('seguindo_1.png'):
        pyautogui.click('seguindo_1.png')

    if pyautogui.locateOnScreen('deixardeseguir_1.png'):
        pyautogui.click('deixardeseguir_1.png')
             
        #time.sleep(random.randint(3,10))
        #pyautogui.press('tab',press=3)
        print('Encontrei com Método 1: Click')
    else:
        if pyautogui.locateOnScreen('baixo.png'):
            time.sleep(random.randint(1,3))
            #pyautogui.press('tab', presses=8)
            pyautogui.click('baixo.png')
            posicao_atual = pyautogui.position()
            time.sleep(1)
            pyautogui.click(posicao_atual)
            time.sleep(1)
            pyautogui.click(posicao_atual)
            time.sleep(1)
            pyautogui.click(posicao_atual)
            time.sleep(1)
            pyautogui.click(posicao_atual)
            time.sleep(1)
            pyautogui.click(posicao_atual)
            time.sleep(1)
            pyautogui.click(posicao_atual)
            
            print('Descendo a tela!')
        
   

    print(contador)
# Out:
# Descendo a tela!
# 1
# Encontrei com Método 1: Click
# 2
# Encontrei com Método 1: Click
# 3
# Encontrei com Método 1: Click
# 4
# Encontrei com Método 1: Click
# 5
# Encontrei com Método 1: Click
# 6
# Descendo a tela!
# 7
# Encontrei com Método 1: Click
# 8
# Encontrei com Método 1: Click
# 9
# Encontrei com Método 1: Click
# 10
# Descendo a tela!
# 11
# Encontrei com Método 1: Click
# 12
# Encontrei com Método 1: Click
# 13
# Encontrei com Método 1: Click
# 14
# Encontrei com Método 1: Click
# 15
# Encontrei com Método 1: Click
# 16
# Descendo a tela!
# 17
# Encontrei com Método 1: Click
# 18
# Encontrei com Método 1: Click
# 19
# Encontrei com Método 1: Click
# 20
# Encontrei com Método 1: Click
# 21
# Descendo a tela!
# 22
# Encontrei com Método 1: Click
# 23
# Encontrei com Método 1: Click
# 24
# Encontrei com Método 1: Click
# 25
# Encontrei com Método 1: Click
# 26
# Descendo a tela!
# 27
# Encontrei com Método 1: Click
# 28
# Encontrei com Método 1: Click
# 29
# ...

# %%
pyautogui.position()
# Out:
# Point(x=615, y=580)
